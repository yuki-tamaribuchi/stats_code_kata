# %% [markdown]
# <a href="https://colab.research.google.com/github/yuki-tamaribuchi/stats_code_kata/blob/master/iris_additivechi2_and_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
import numpy as np
from sklearn.kernel_approximation import AdditiveChi2Sampler
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
X,y=load_iris(True)

# %%
X=X[:,:2]

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
ax.scatter(X[:,0],X[:,1],c=y,cmap='winter')

# %%
chi2_sampler=AdditiveChi2Sampler()
X_features=chi2_sampler.fit_transform(X)

# %%
X_features.shape
# Out:
# (150, 6)

# %%
fig=plt.figure()
ax=Axes3D(fig)
ax.scatter(X_features[:,0],X_features[:,1],X_features[:,2],c=y,cmap='winter')
